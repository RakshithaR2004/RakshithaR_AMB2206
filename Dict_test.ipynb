# %%
crop={'Rice','Wheat','Maize'}
Yield={120,85,60}

#to find no.of crops cultivated by the farmer

print("No.of crops cultivated by the farmer =",len(crop))
# Out:
# No.of crops cultivated by the farmer = 3

# %%
#Display the yield of wheat(without get method)
d={'Rice':120,'Wheat':85,'Maize':60}

print("The yield of wheat is :",d['Wheat'],'q/acre')
# Out:
# The yield of wheat is : 85 q/acre

# %%
#To add a crop pulses with yield 45 and display complete list

d['Pules']=45
print("Dictionary after adding pulses :",d)
# Out:
# Dictionary after adding pulses : {'Rice': 120, 'Wheat': 85, 'Maize': 60, 'Pules': 45}

# %%
#Update the yield of rice to 130 and display complete dictionary
d={'Rice': 120, 'Wheat': 85, 'Maize': 60, 'Pules': 45}
d['Rice']=130
print("Dictionary after updating the yield of rice :",d)
# Out:
# Dictionary after updating the yield of rice : {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pules': 45}

# %%
#To display the crops and their yield cultivated by the farmer
d={'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pules': 45}

print("The crops cultivated by farmer are :",list(d.keys()))
print("The yield of crops cultivated by farmer are :",list(d.values()))
# Out:
# The crops cultivated by farmer are : ['Rice', 'Wheat', 'Maize', 'Pules']
# The yield of crops cultivated by farmer are : [130, 85, 60, 45]

# %%
#To check whether sugarcane is grown by the farmer

d={'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pules': 45}

print('Is Sugarcane grown by farmer :','Sugarcane' in d)
# Out:
# Is Sugarcane grown by farmer : False

# %%
#To increase yield of wheat by 10

d={'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pules': 45}
d['Wheat']=d['Wheat']+10

print("The updated yield of wheat is:",d['Wheat'])
print("THe updated list is: ",d)
# Out:
# The updated yield of wheat is: 95
# THe updated list is:  {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}

# %%
#calculate total yield of all crops

d={'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}

print("The total yield =",sum(d.values()))
# Out:
# The total yield = 425

# %%
#Display each crop and its yield using loop

d={'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}

for k,v in d.items():
  print(k,':',v)
# Out:
# Rice : 130
# Wheat : 95
# Maize : 60
# Pules : 45

# %%
#Copy the dict and print the values of new dict

d={'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
n_d=d.copy()

print("d=",d)
print("n_d=",n_d)
# Out:
# d= {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
# n_d= {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}

# %%
#To clear the elements from new dictionary

d={'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
n_d=d.copy()

print("d=",d)
print("n_d=",n_d)

n_d.clear()
print("\nn_d: ",n_d)
# Out:
# d= {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
# n_d= {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
#
# n_d:  {}

# %%
data={'rice':120,'wheat':85,'maize':60}
print("number of crops grown by farmer",len(data))
keylist=list(data.keys())
vallist=list(data.values())
print(keylist)
print(vallist)
# Out:
# number of crops grown by farmer 3
# ['rice', 'wheat', 'maize']
# [120, 85, 60]

# %%
data={'rice':120,'wheat':85,'maize':60}
print("yeild of wheat ",data["wheat"])
# Out:
# yeild of wheat  85

# %%
data["pulses"]=45

# %%
print(data)
# Out:
# {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
data["rice"]=130

# %%
print(data)
# Out:
# {'rice': 130, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
print("crops cultivated by farmers ",list(data.keys()))
# Out:
# crops cultivated by farmers  ['rice', 'wheat', 'maize', 'pulses']

# %%
print(" yeild of crops cultivated by farmers ",list(data.values()))
# Out:
#  yeild of crops cultivated by farmers  [130, 85, 60, 45]

# %%
print("sugarcane is present ","sugarcane" in data.keys())
# Out:
# sugarcane is present  False

# %%
data["wheat"]=data["wheat"]+10

# %%
print(data)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
print("sum of yeild",sum(data.values()))
# Out:
# sum of yeild 330

# %%
for i,j in data.items():
 print(i,j)
# Out:
# rice 130
# wheat 95
# maize 60
# pulses 45

# %%
data={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
data2=data.copy()
print(data)
print(data2)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
data2.clear()

# %%
print(data2)
# Out:
# {}

# %%
print(data)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
data={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
del data("maize")
print(data)

# %%
d={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

i=input("Enter the crop name : ")

if i in d:
  print(d[i])
else:
  print("The entered crop is not present in d")

# %%
#how to get the yeild of crops hrom the dict with proper caption

d={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
print(" yeild:",d.get("carrot","not cultivated"))
# Out:
#  yeild: not cultivated

# %%
 #To remove maize from dictionary
d={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
d.pop('maize')
print(d)
# Out:
# {'rice': 130, 'wheat': 95, 'pulses': 45}

# %%
#To remove maize from dictionary
d={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

del d['maize']
print(d)
# Out:
# {'rice': 130, 'wheat': 95, 'pulses': 45}

# %%
d={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

del d['maize']
print(d)              #After removing maize from dictionary, if u try to print Maize it wil show "Key error"

print(d['maize'])
# Out:
# {'rice': 130, 'wheat': 95, 'pulses': 45}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-583964634.py in <cell line: 0>()
#       5 print(d)
#       6
# ----> 7 print(d['maize'])
#
# KeyError: 'maize'

# %%
d={'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
n_d=d.copy()

print("d=",d)
print("n_d=",n_d)

n_d.clear()              #After clearing the list, if we try to print the dictionary we will get empty dictionary
print("\nn_d: ",n_d)

del n_d                  #After deleting the list, if we try to print the dictionary we will "Name error"
print("\nn_d: ",n_d)
# Out:
# d= {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
# n_d= {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pules': 45}
#
# n_d:  {}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3027662460.py in <cell line: 0>()
#       9
#      10 del n_d
# ---> 11 print("\nn_d: ",n_d)
#
# NameError: name 'n_d' is not defined
