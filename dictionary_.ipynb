# %%
i=7
sum=0
while i!=0:
  if sum>50:
    break
  print(i)
  sum=sum+i
  i+=5
print(sum)
# Out:
# 7
# 12
# 17
# 22
# 58

# %%
#dictionary
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
print("dictionary ",cgpa)
print("total elements ",len(cgpa))
print("type of object ",type(cgpa))
print("cgpa of 1",cgpa[1])
print("cgpa of 4 ",cgpa[4])
print("cga of 5 ",cgpa[8])
for k in cgpa:
  print("cgpa of ",k,"  ",cgpa[k])
# Out:
# dictionary  {1: 8.9, 2: 5.7, 4: 6.7, 7: 9.1, 8: 5.3}
# total elements  5
# type of object  <class 'dict'>
# cgpa of 1 8.9
# cgpa of 4  6.7
# cga of 5  5.3
# cgpa of  1    8.9
# cgpa of  2    5.7
# cgpa of  4    6.7
# cgpa of  7    9.1
# cgpa of  8    5.3

# %%
print("dictionary ",cgpa)
print("keys ",cgpa.keys())
print("values  ",cgpa.values())
# Out:
# dictionary  {1: 8.9, 2: 5.7, 4: 6.7, 7: 9.1, 8: 5.3}
# keys  dict_keys([1, 2, 4, 7, 8])
# values   dict_values([8.9, 5.7, 6.7, 9.1, 5.3])

# %%
#addition of elements
cgpa[3]=8.6
print("after adding (3)",cgpa)
cgpa[9]=10
print("after adding (9)",cgpa)
# fo udation the key no is rereturn
cgpa[9]=9.9
print(" after updatio  ",cgpa)
# Out:
# after adding (3) {1: 8.9, 2: 5.7, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6}
# after adding (9) {1: 8.9, 2: 5.7, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6, 9: 10}
#  after updatio   {1: 8.9, 2: 5.7, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6, 9: 9.9}

# %%
# deletion of elements
cgpa=cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
del cgpa[1]
del cgpa[8]
print("\n after deleting(1)",cgpa)
print("\n after deleting (8)",cgpa)
del cgpa
print(cgpa)
# Out:
#  after deleting(1) {2: 5.7, 4: 6.7, 7: 9.1}
#
#  after deleting (8) {2: 5.7, 4: 6.7, 7: 9.1}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3016955268.py in <cell line: 0>()
#       6 print("\n after deleting (8)",cgpa)
#       7 del cgpa
# ----> 8 print(cgpa)
#
# NameError: name 'cgpa' is not defined

# %%
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
cgpa.clear()
print(cgpa)
# Out:
# {}

# %%
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
s=0
for i in cgpa:
  s=s+cgpa[i]
print("sum ",s)
print("average",s/len(cgpa))
print("average",s//len(cgpa))
# Out:
# sum  35.699999999999996
# average 7.139999999999999
# average 7.0

# %%
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
print("sum ",sum(cgpa.values()))
print("average",sum(cgpa.values())/len(cgpa))
print("average",sum(cgpa.values())//len(cgpa))
# Out:
# sum  35.7
# average 7.140000000000001
# average 7.0

# %%
cgpa={1:8.9,2:5.7,4:6.7,7:9.1,8:5.3}
print(min(cgpa))
print(max(cgpa))
# Out:
# 1
# 8

# %%
print(min(cgpa.values()))
print(max(cgpa.values()))
# Out:
# 5.3
# 9.1

# %%
print(cgpa.items())
print(cgpa.values())
print(cgpa.keys())print(cgpa.items())
print(cgpa.values())
print(cgpa.keys())
print("dictionary  ",cgpa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-632592659.py in <cell line: 0>()
# ----> 1 print("dictionary  ",cgpa)
#
# NameError: name 'cgpa' is not defined

# %%
age={'A':14,'B':15,'C':16,'D':17}
print("Dictionary",age)
print("total elements",len(age))
print("type of object",type(age))
# Out:
# Dictionary {'A': 14, 'B': 15, 'C': 16, 'D': 17}
# total elements 4
# type of object <class 'dict'>

# %%
print("Age of A", age['A'])
print("Age of B", age['B'])
print("Age of C", age['C'])
print("Age of E", age['E'])
# Out:
# Age of A 14
# Age of B 15
# Age of C 16
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3313710611.py in <cell line: 0>()
#       2 print("Age of B", age['B'])
#       3 print("Age of C", age['C'])
# ----> 4 print("Age of E", age['E'])
#
# KeyError: 'E'

# %%
#traverse dictionary
age={'A':14,'B':15,'C':16,'D':17}
for a in age:
  print("Age of",a,"\n",age[a])

# %%
#Getting keys nd values
print("Keys:-",age.keys())
print("Values:-",age.values())

# %%
age={'A':14,'B':15,'C':16,'D':17}
age['G']=20
print("After ading (G)",age)
age['E']=18   #adding new key an value
print("After adding E",age)
age['D']=8.6    #updating the value
print("After updating D",age)

# %%
age={'A': 14, 'B': 15, 'C': 16, 'D': 8.6, 'G': 20, 'E': 18}
del age['E']
del age['G']
print("After deleting ",age)

# %%
del age
print(age)

# %%
#sum/ avg of all values
age={'A':14,'B':15,'C':16,'D':17}
print("ages are",age)
s=0
for a in age:
  s=s+age[a]
print("Sum",s)
print("Average",s/len(age)) # / to get float value
print("Average",s//len(age))  # // to get integer

# %%
age={'A':14,'B':15,'C':16,"D":17}
print("ages are",age)
del sum
print("Sum",sum(age.values()))
print("Average",sum(age.values())/len(age))
print("Average",sum(age.values())//len(age))
# Out:
# ages are {'A': 14, 'B': 15, 'C': 16, 'D': 17}
# Sum 62
# Average 15.5
# Average 15

# %%
age={'A':14,'B':15,'C':16,"D":17}
print(min(age))
print(max(age))
print(min(age.values()))
print(max(age.values()))
# Out:
# A
# D
# 14
# 17

# %%
#13th Jan
#Assignment
farm={"Rice":120,"Wheat":85,"Maize":60}
print("no. of crops cultivated by farmer",len(farm))
# Out:
# no. of crops cultivated by farmer 3

# %%
#display the yield of wheat
farm={"Rice":120,"Wheat":85,"Maize":60}
print("Yield of wheat in Q/acre=",farm["Wheat"])  # without using get
print("Yield of wheat=",farm.get("Wheat"))       # using get
# Out:
# Yield of wheat in Q/acre= 85
# Yield of wheat= 85

# %%
#adding new crop- pulses
farm={"Rice":120,"Wheat":85,"Maize":60}
farm["pulses"]=45
print("After adding pulses",farm)
# Out:
# After adding pulses {'Rice': 120, 'Wheat': 85, 'Maize': 60, 'pulses': 45}

# %%
#updating the yield of rice
farm={"Rice":120,"Wheat":85,"Maize":60,"Pulses":45}
farm["Rice"]=130
print("Updated dictionary ----->",farm)
# Out:
# Updated dictionary -----> {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
# displaying all crop names cultivated by farmers
farm={"Rice":120,"Wheat":85,"Maize":60,"Pulses":45}
print("Crops grown are-->",list(farm.keys()))
# Out:
# Crops grown are--> ['Rice', 'Wheat', 'Maize', 'Pulses']

# %%
#displaying all crop yields
farm={"Rice":120,"Wheat":85,"Maize":60,"Pulses":45}
print("Crop yields are-->",list(farm.values()))
# Out:
# Crop yields are--> [120, 85, 60, 45]

# %%
farm={"Rice":120,"Wheat":85,"Maize":60,"Pulses":45}
print("Checking whether sugarcane is cultivated or not \n","sugarcane" in farm.keys())
# Out:
# Checking whether sugarcane is cultivated or not
#  False

# %%
farm={"Rice":120,"Wheat":85,"Maize":60,"Pulses":45}
farm["Wheat"]=farm["Wheat"]+10
print("After updating yield of wheat ",farm)
# Out:
# After updating yield of wheat  {'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}

# %%
#Calculating total yield
farm={'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
s=0
for i in farm:
  s=s+farm[i]
print("Total yield =",s) #sum(farm.values())
# Out:
# Total yield = 320

# %%
farm={'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
print("Total yield =",sum(farm.values()))
# Out:
# Total yield = 320

# %%
# Displaying each crop and its yield using loop
farm={'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
for c,y in farm.items():
   print(c,"=",y)
# Out:
# Rice = 120
# Wheat = 95
# Maize = 60
# Pulses = 45

# %%
farm={'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
for c in farm:
  print(c,"=",farm[c])
# Out:
# Rice = 120
# Wheat = 95
# Maize = 60
# Pulses = 45

# %%
farm={'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
for i in zip(farm.keys(),farm.values()):
  print(i)
# Out:
# ('Rice', 120)
# ('Wheat', 95)
# ('Maize', 60)
# ('Pulses', 45)

# %%
# Copying the dictionary to a new dictionary
farm={'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
new_farm= farm.copy()
print(new_farm)
print("Values of new dictionary",list(new_farm.values()))
# Out:
# {'Rice': 120, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
# Values of new dictionary [120, 95, 60, 45]

# %%
# Clearing the elements from new dictionary
new_farm.clear()
print(new_farm)
# Out:
# {}

# %%
print("Yield of Jowar",farm["Jowar"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1730390616.py in <cell line: 0>()
# ----> 1 print("Yield of Jowar",farm["Jowar"])
#
# KeyError: 'Jowar'

# %%
for i in farm:
  if i=="Jowar":
    print("The crop is present")
else:
    print("Not present")
# Out:
# Not present

# %%
 print( if "Jowar" in farm ("Present") else ("Not present"))
# Out:
#   File "/tmp/ipython-input-3129436172.py", line 1
#     print( if "Jowar" in farm ("Present") else ("Not present"))
#            ^
# SyntaxError: invalid syntax

# %%
print("Jowar yield",farm.get("Jowar"))
# Out:
# Jowar yield None

# %%
print("Jowar yield -->",farm.get("Jowar","Not cultivated"))
# Out:
# Jowar yield --> Not cultivated

# %%
print("Rice yield-->",farm.get("Rice"))
# Out:
# Rice yield--> 120

# %%
# remove maize from dictionary
farm.pop("Maize")
print("After removing maize",farm)
# Out:
# After removing maize {'Rice': 120, 'Wheat': 85}

# %%
farm.pop("Maize")
print("After removing maize",farm)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2799725985.py in <cell line: 0>()
# ----> 1 farm.pop("Maize")
#       2 print("After removing maize",farm)
#
# KeyError: 'Maize'

# %%
del new_farm
print(new_farm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3761757303.py in <cell line: 0>()
#       1 del new_farm
# ----> 2 print(new_farm)
#
# NameError: name 'new_farm' is not defined
